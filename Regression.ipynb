# %%
data <- read.csv("Data.csv")
head(data)
# Out:
#   x y
# 1 1 3
# 2 2 4
# 3 3 8
# 4 4 4
# 5 5 6
# 6 6 9

# %%
library(ggplot2)
ggplot(data = data, aes(x=x,y=y)) + geom_point()
# Out:
# plot without title

# %%
model <- lm(formula = y ~ x, data=data)

# %%
summary(model)
# Out:
# Call:
# lm(formula = y ~ x, data = data)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -10.5338  -3.5395   0.1353   4.0733   9.2857
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -10.2632     2.7929  -3.675  0.00173 **
# x             3.9774     0.2331  17.060 1.47e-12 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 6.012 on 18 degrees of freedom
# Multiple R-squared:  0.9418,	Adjusted R-squared:  0.9385
# F-statistic:   291 on 1 and 18 DF,  p-value: 1.47e-12

# %%
ggplot(data, aes(x=x, y=y)) + geom_point() + stat_smooth(method = lm)
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# plot without title

# %%
ggplot(data, aes(x=x, y=y)) + geom_point() + stat_smooth()
# Out:
# `geom_smooth()` using method = 'loess' and formula = 'y ~ x'
# plot without title
